# %%
import pandas as pd

# %%
dd=pd.read_csv('diamonds.csv')

# %%
dd.head()
# Out:
#    uno  carat      cut color clarity  depth  table  price     x     y     z
# 0    1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1    2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2    3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3    4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4    5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
dd=dd.drop('uno',axis=1)

# %%
x=dd.drop(['cut','color','clarity'],axis=1)

# %%
x.corr()
# Out:
#           carat     depth     table     price         x         y         z
# carat  1.000000  0.028224  0.181618  0.921591  0.975094  0.951722  0.953387
# depth  0.028224  1.000000 -0.295779 -0.010647 -0.025289 -0.029341  0.094924
# table  0.181618 -0.295779  1.000000  0.127134  0.195344  0.183760  0.150929
# price  0.921591 -0.010647  0.127134  1.000000  0.884435  0.865421  0.861249
# x      0.975094 -0.025289  0.195344  0.884435  1.000000  0.974701  0.970772
# y      0.951722 -0.029341  0.183760  0.865421  0.974701  1.000000  0.952006
# z      0.953387  0.094924  0.150929  0.861249  0.970772  0.952006  1.000000

# %%
dd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
dd['carat']=dd['carat'].astype(int)

# %%
dd['depth']=dd['depth'].astype(int)

# %%
dd['table']=dd['table'].astype(int)

# %%
dd['x']=dd['x'].astype(int)

# %%
dd['y']=dd['y'].astype(int)

# %%
dd['z']=dd['z'].astype(int)

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()

# %%
dd['cut']=l.fit_transform(dd['cut'])

# %%
dd['color']=l.fit_transform(dd['color'])

# %%
dd['clarity']=l.fit_transform(dd['clarity'])

# %%
dd.head()
# Out:
#    carat  cut  color  clarity  depth  table  price  x  y  z
# 0      0    2      1        3     61     55    326  3  3  2
# 1      0    3      1        2     59     61    326  3  3  2
# 2      0    1      1        4     56     65    327  4  4  2
# 3      0    3      5        5     62     58    334  4  4  2
# 4      0    1      6        3     63     58    335  4  4  2

# %%
x=dd.drop('price',axis=1)

# %%
y=dd['price']

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2)

# %%
print(xtrain)
# Out:
#        carat  cut  color  clarity  depth  table  x  y  z
# 34500      0    1      5        6     59     61  4  4  2
# 19521      1    3      3        6     62     59  6  6  3
# 8565       0    4      3        2     62     58  6  6  3
# 51303      0    1      1        2     63     57  4  4  2
# 37269      0    2      4        4     62     54  4  4  2
# ...      ...  ...    ...      ...    ...    ... .. .. ..
# 2408       0    2      0        5     62     57  5  5  3
# 53579      0    2      2        2     62     55  5  5  3
# 10333      1    4      1        2     58     58  6  6  3
# 36254      0    2      1        5     62     56  4  4  2
# 20156      1    2      0        4     61     56  6  6  4
#
# [43152 rows x 9 columns]

# %%
print(xtest)
# Out:
#        carat  cut  color  clarity  depth  table  x  y  z
# 25400      1    3      1        2     59     58  7  7  4
# 9255       1    2      5        3     62     56  6  6  4
# 16868      1    2      3        3     62     57  7  7  4
# 46576      0    4      1        5     61     57  5  5  3
# 680        0    2      2        5     60     59  5  5  3
# ...      ...  ...    ...      ...    ...    ... .. .. ..
# 20299      1    4      6        7     61     60  7  7  4
# 13781      1    4      0        2     61     58  6  6  3
# 7208       0    2      1        3     62     55  6  6  3
# 39809      0    3      5        3     62     60  5  5  3
# 6796       0    4      3        4     61     56  6  6  3
#
# [10788 rows x 9 columns]

# %%
print(ytrain)
# Out:
# 34500     867
# 19521    8154
# 8565     4435
# 51303     544
# 37269     482
#          ...
# 2408     3179
# 53579    2697
# 10333    4766
# 36254     935
# 20156    8612
# Name: price, Length: 43152, dtype: int64

# %%
print(ytest)
# Out:
# 25400    14107
# 9255      4560
# 16868     6730
# 46576     1785
# 680       2850
#          ...
# 20299     8712
# 13781     5619
# 7208      4191
# 39809     1097
# 6796      4116
# Name: price, Length: 10788, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
model.predict(xtest)
# Out:
# array([9171.56966611, 6478.48264752, 8964.4654153 , ..., 4637.84505151,
#        1346.60676957, 4648.75686364], shape=(10788,))

# %%
print(ytest)
# Out:
# 25400    14107
# 9255      4560
# 16868     6730
# 46576     1785
# 680       2850
#          ...
# 20299     8712
# 13781     5619
# 7208      4191
# 39809     1097
# 6796      4116
# Name: price, Length: 10788, dtype: int64

# %%
model.score(xtest,ytest)
# Out:
# 0.8443123587461445
