# %%
import pandas as pd

# %%
df=pd.read_csv('Automobile.csv')

# %%
df=df.drop(['index'],axis=1)

# %%
df
# Out:
#         company   body-style  wheel-base  length engine-type num-of-cylinders  \
# 0   alfa-romero  convertible        88.6   168.8        dohc             four
# 1   alfa-romero  convertible        88.6   168.8        dohc             four
# 2   alfa-romero    hatchback        94.5   171.2        ohcv              six
# 3          audi        sedan        99.8   176.6         ohc             four
# 4          audi        sedan        99.4   176.6         ohc             five
# ..          ...          ...         ...     ...         ...              ...
# 56   volkswagen        sedan        97.3   171.7         ohc             four
# 57   volkswagen        sedan        97.3   171.7         ohc             four
# 58   volkswagen        sedan        97.3   171.7         ohc             four
# 59        volvo        sedan       104.3   188.8         ohc             four
# 60        volvo        wagon       104.3   188.8         ohc             four
#
#     horsepower  average-mileage    price
# 0          111               21  13495.0
# 1          111               21  16500.0
# 2          154               19  16500.0
# 3          102               24  13950.0
# 4          115               18  17450.0
# ..         ...              ...      ...
# 56          85               27   7975.0
# 57          52               37   7995.0
# 58         100               26   9995.0
# 59         114               23  12940.0
# 60         114               23  13415.0
#
# [61 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   company           61 non-null     object
#  1   body-style        61 non-null     object
#  2   wheel-base        61 non-null     float64
#  3   length            61 non-null     float64
#  4   engine-type       61 non-null     object
#  5   num-of-cylinders  61 non-null     object
#  6   horsepower        61 non-null     int64
#  7   average-mileage   61 non-null     int64
#  8   price             58 non-null     float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 4.4+ KB

# %%
df['price'].fillna(15387,inplace=True)
# Out:
# C:\Users\nihal\AppData\Local\Temp\ipykernel_5392\3071471888.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['price'].fillna(15387,inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()

# %%
df['body-style']=l.fit_transform(df['body-style'])

# %%
df['company']=l.fit_transform(df['company'])

# %%
df['engine-type']=l.fit_transform(df['engine-type'])

# %%
df['num-of-cylinders']=l.fit_transform(df['num-of-cylinders'])

# %%
x=df.drop(['price'],axis=1)

# %%
y=df['price']

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
model.predict(xtest)
# Out:
# array([41382.44701463,  1662.20736762,  7649.68161488, 17175.65228987,
#         5875.04987309, 13812.7301097 , 17178.04249204,  4588.02070805,
#        19504.79255029, 18081.2301198 ,  5381.54887853,  1716.93650852,
#        14479.98207165])

# %%
model.score(xtest,ytest)
# Out:
# 0.8174343618586664

# %%
print(ytest)
# Out:
# 26    36000.0
# 18     7295.0
# 16     6377.0
# 60    13415.0
# 42     6849.0
# 19    12945.0
# 3     13950.0
# 13     5151.0
# 9     20970.0
# 54    15750.0
# 50     6488.0
# 53     8778.0
# 4     17450.0
# Name: price, dtype: float64

# %%
print(xtest)
# Out:
#     company  body-style  wheel-base  length  engine-type  num-of-cylinders  \
# 26        7           3       102.0   191.7            5                 5
# 18        5           4        96.5   157.1            3                 2
# 16        4           2        93.7   157.3            3                 2
# 60       15           4       104.3   188.8            3                 2
# 42       11           3        94.5   165.3            3                 2
# 19        5           3        96.5   175.4            3                 2
# 3         1           3        99.8   176.6            3                 2
# 13        3           2        88.4   141.1            2                 4
# 9         2           3       101.2   176.8            3                 3
# 54       13           4       104.5   187.8            0                 3
# 50       13           2        95.7   158.7            3                 2
# 53       13           4        95.7   169.7            3                 2
# 4         1           3        99.4   176.6            3                 1
#
#     horsepower  average-mileage
# 26         262               13
# 18          76               30
# 16          68               31
# 60         114               23
# 42          69               31
# 19         101               24
# 3          102               24
# 13          48               47
# 9          121               21
# 54         156               19
# 50          62               31
# 53          62               27
# 4          115               18

# %%
model.predict([[14,2,95.7,159.1,3,2,69,30]])
# Out:
# c:\Users\nihal\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([5530.5194713])
