# %%
import pandas as pd

# %%
df=pd.read_csv('loan_data.csv')
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 1            21.0        female      High School        12282.0
# 2            25.0        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 4            24.0          male           Master        66135.0
# ...           ...           ...              ...            ...
# 44995        27.0          male        Associate        47971.0
# 44996        37.0        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_age                      45000 non-null  float64
#  1   person_gender                   45000 non-null  object
#  2   person_education                45000 non-null  object
#  3   person_income                   45000 non-null  float64
#  4   person_emp_exp                  45000 non-null  int64
#  5   person_home_ownership           45000 non-null  object
#  6   loan_amnt                       45000 non-null  float64
#  7   loan_intent                     45000 non-null  object
#  8   loan_int_rate                   45000 non-null  float64
#  9   loan_percent_income             45000 non-null  float64
#  10  cb_person_cred_hist_length      45000 non-null  float64
#  11  credit_score                    45000 non-null  int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
df['person_gender']=l.fit_transform(df['person_gender'])

# %%
l1=LabelEncoder()
df['person_education']=l1.fit_transform(df['person_education'])

# %%
l2=LabelEncoder()
df['person_home_ownership']=l2.fit_transform(df['person_home_ownership'])

# %%
l3=LabelEncoder()
df['loan_intent']=l3.fit_transform(df['loan_intent'])

# %%
l4=LabelEncoder()
df['previous_loan_defaults_on_file']=l4.fit_transform(df['previous_loan_defaults_on_file'])

# %%
x=df.drop(['loan_status'],axis=1)

# %%
y=df['loan_status']

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model=KNeighborsClassifier()
model.fit(xtrain,ytrain)
# Out:
# KNeighborsClassifier()

# %%
model.score(xtest,ytest)
# Out:
# 0.8391111111111111

# %%
model1=KNeighborsClassifier(n_neighbors=10)
model1.fit(xtrain,ytrain)
model1.score(xtest,ytest)
# Out:
# 0.843

# %%
model2=KNeighborsClassifier(n_neighbors=50)
model2.fit(xtrain,ytrain)
model2.score(xtest,ytest)
# Out:
# 0.8456666666666667

# %%
model3=KNeighborsClassifier(n_neighbors=75)
model3.fit(xtrain,ytrain)
model3.score(xtest,ytest)
# Out:
# 0.8431111111111111

# %%
a=int(input('Enter age:'))
b=input('Enter Gender:')
b=b.lower()
b=l.transform([b])[0]
c=input('Enter Education:')
c=c.capitalize()
c=l1.transform([c])[0]
d=int(input('Enter Income:'))
e=int(input('Enter Experience:'))
f=input('Enter home ownership:')
f=f.upper()
f=l2.transform([f])[0]
g=int(input('Enter loan amount:'))
h=input('Enter loan intent:')
h=h.upper()
h=l3.transform([h])[0]
i=float(input('Enter intrest rate'))
j=float(input('Enter loan percent income'))
k=float(input('Enter cred history'))
m=int(input('Enter credit score'))
n=input('Previous loan in file')
n=n.capitalize()
n=l4.transform([n])[0]
model2.predict([[a,b,c,d,e,f,g,h,i,j,k,m,n]])
# Out:
# c:\Users\nihal\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array([1])
